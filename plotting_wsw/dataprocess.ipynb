# %%
import json
import pandas as pd

df = pd.read_json('ArkOperators_final.json')
df
# Out:
#              代号                       英文代号                    本名  \
# 0          推进之王                      Siege        亚历山德莉娜·维娜·维多利亚
# 1            风笛                    Bagpipe                 菲奥娜·杨
# 2            嵯峨                       Saga                   NaN
# 3            琴柳                   Saileach                  简·薇洛
# 4            焰尾                  Flametail                    索娜
# ..          ...                        ...                   ...
# 289       正义骑士号           "Justice Knight"                   NaN
# 290     泰拉大陆调查团  Terra Research Commission         工匠猫、学者猫、随从艾露猫
# 291    Lancet-2                        NaN  雷神存在者S-Typer62六轮作业平台
# 292  U-Official                        NaN                   尤里卡
# 293     THRM-EX                 Thermal-EX                   NaN
#
#                                           别号   性别  \
# 0            维娜、推王、王小姐、卡手之王、阿尔推莉雅、锤呆、王维娜、王大锤    女
# 1                                   拖拉机少女、二乃    女
# ...

# %%
for i in range(294):
    if (df['性别'].isnull())[i]: 
        df['性别'][i] = df['设定性别'][i]

df
# Out:
#              代号                       英文代号                    本名  \
# 0          推进之王                      Siege        亚历山德莉娜·维娜·维多利亚
# 1            风笛                    Bagpipe                 菲奥娜·杨
# 2            嵯峨                       Saga                   NaN
# 3            琴柳                   Saileach                  简·薇洛
# 4            焰尾                  Flametail                    索娜
# ..          ...                        ...                   ...
# 289       正义骑士号           "Justice Knight"                   NaN
# 290     泰拉大陆调查团  Terra Research Commission         工匠猫、学者猫、随从艾露猫
# 291    Lancet-2                        NaN  雷神存在者S-Typer62六轮作业平台
# 292  U-Official                        NaN                   尤里卡
# 293     THRM-EX                 Thermal-EX                   NaN
#
#                                           别号   性别  \
# 0            维娜、推王、王小姐、卡手之王、阿尔推莉雅、锤呆、王维娜、王大锤    女
# 1                                   拖拉机少女、二乃    女
# ...

# %%
df.drop(columns= '设定性别')
# Out:
#              代号                       英文代号                    本名  \
# 0          推进之王                      Siege        亚历山德莉娜·维娜·维多利亚
# 1            风笛                    Bagpipe                 菲奥娜·杨
# 2            嵯峨                       Saga                   NaN
# 3            琴柳                   Saileach                  简·薇洛
# 4            焰尾                  Flametail                    索娜
# ..          ...                        ...                   ...
# 289       正义骑士号           "Justice Knight"                   NaN
# 290     泰拉大陆调查团  Terra Research Commission         工匠猫、学者猫、随从艾露猫
# 291    Lancet-2                        NaN  雷神存在者S-Typer62六轮作业平台
# 292  U-Official                        NaN                   尤里卡
# 293     THRM-EX                 Thermal-EX                   NaN
#
#                                           别号   性别  \
# 0            维娜、推王、王小姐、卡手之王、阿尔推莉雅、锤呆、王维娜、王大锤    女
# 1                                   拖拉机少女、二乃    女
# ...

# %%
df.columns
# Out:
# Index(['代号', '英文代号', '本名', '别号', '性别', '发色', '瞳色', '身高', '生日', '种族', '职业',
#        '职能', '专精', '萌点', '出身地区', '所属团体', '个人状态', '角色EP', '画师', '生命上限', '攻击',
#        '防御', '法术抗性', '再部署', '部署费用', '阻挡数', '攻击速度', '职业细分', '活动范围', '位置', '体重',
#        '年龄', '出生地区', '干员编号', '所属团队', '三围', '角色歌', '出厂日', '产地', '重量', '设定性别'],
#       dtype='object')

# %%
for i in range(294):
    if not (df['身高'].isnull())[i]: 
        df['身高'][i]= int(df['身高'][i])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\4191425825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['身高'][i]= int(df['身高'][i])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\4191425825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['身高'][i]= int(df['身高'][i])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\4191425825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.columns
# Out:
# Index(['代号', '英文代号', '本名', '别号', '性别', '发色', '瞳色', '身高', '生日', '种族', '职业',
#        '职能', '专精', '萌点', '出身地区', '所属团体', '个人状态', '角色EP', '画师', '生命上限', '攻击',
#        '防御', '法术抗性', '再部署', '部署费用', '阻挡数', '攻击速度', '职业细分', '活动范围', '位置', '体重',
#        '年龄', '出生地区', '干员编号', '所属团队', '三围', '角色歌', '出厂日', '产地', '重量', '设定性别'],
#       dtype='object')

# %%
for i in range(294):
    df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
    
df['攻击速度']
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\932035774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\932035774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\932035774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
if(df['攻击速度'].isnull()[i]) :print(i)
for i in range(294):
    if type(df['攻击速度'][i]) == str: 
        print(i, df['攻击速度'][i])
        df['攻击速度'][i] = float(df['攻击速度'][i][:-1])
        print(i, df['攻击速度'][i])
# Out:
# 28 2.1秒
# 28 2.1
# 130 2.1秒
# 130 2.1
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\108283328.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i][:-1])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\108283328.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i][:-1])

# %%
for i in range(131,294):
    df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\843851312.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\843851312.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['攻击速度'][i] = float(df['攻击速度'][i].split(' ')[1][:-1])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9252\843851312.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.to_csv('ArkModified1.csv')

# %%
if(df['再部署'].isnull()[i]) :print(i)
for i in range(294):
    if type(df['再部署'][i]) == str: 
        print(i, df['再部署'][i])
        df['再部署'][i] = float(df['再部署'][i].split(' ')[-1][:-1])
        #print(i, df['攻击速度'][i])
df
# Out:
# 0 慢 70秒
# 1 慢 70秒
# 2 慢 70秒
# 3 慢 70秒
# 4 慢 70秒
# 5 慢 70秒
# 6 中等 35秒
# 7 慢 70秒
# 8 慢 70秒
# 9 慢 70秒
# 10 慢 70秒
# 11 慢 70秒
# 12 慢 70秒
# 13 慢 70秒
# 14 慢 70秒
# 15 慢 70秒
# 16 慢 70秒
# 17 慢 70秒
# 18 70秒
# 19 慢 70秒
# 20 慢 70秒
# 21 慢 70秒
# 22 慢 70秒
# 23 慢 70秒
# 24 慢 70秒
# 25 慢 70秒
# 26 慢 70秒
# 27 慢 70秒
# 28 慢 70秒
# 29 慢 70秒
# 30 慢 70秒
# 31 慢 70秒
# 32 慢 70秒
# 33 慢 70秒
# 34 慢 70秒
# 35 慢 70秒
# 36 慢 70秒
# 37 慢 70秒
# 38 慢 70秒
# 39 慢 90秒
# 40 慢 70秒
# 41 慢 70秒
# 42 慢 70秒
# 43 慢 70秒
# 44 慢 70秒
# 45 慢 70秒
# 46 慢 70秒
# 47 慢 70秒
# 48 慢 80秒
# 49 慢 70秒
# 50 慢 70秒
# 51 慢 70秒
# 52 慢 70秒
# 53 慢 70秒
# 54 慢 70秒
# 55 慢 70秒
# 56 慢 70秒
# 57 70秒
# 58 慢 90秒
# 59 慢 70秒
# 60 慢 70秒
# 61 慢 70秒
# 62 慢 70秒
# 63 慢 70秒
# 64 慢 70秒
# 65 慢 70秒
# 66 慢 70秒
# 67 慢 70秒
# 68 慢 70秒
# 69 慢 70秒
# 70 慢 70秒
# 71 快 18秒
# 72 慢 70秒
# 73 慢 80秒
# 74 慢 70秒
# 75 中等 25秒
# 76 慢 70秒
# 77 慢 70秒
# 78 快 18秒
# 79 快 18秒
# 80 中等 25秒
# 81 慢 70秒
# 82 慢 70秒
# 83 慢 70秒
# 84 慢 70秒
# 85 慢 70秒
# 86 慢 70秒
# 87 慢 80秒
# 88 慢 70秒
# 89 中等 35秒
# 90 中等 35秒
# ...

# %%
df['再部署']
for i in  range(294):
    if type(df['再部署'][i]) != float:
        print(i,df['再部署'][i])

# %%
df['hp1'] = [int(i.split('/')[0]) for i in df['生命上限']]
df['hp2'] = [int(i.split('/')[1]) for i in df['生命上限']]

# %%
df['hp2']
# Out:
# 0      2251
# 1      2484
# 2      2205
# 3      1835
# 4      2138
#        ...
# 289     495
# 290     518
# 291     435
# 292     385
# 293    1443
# Name: hp2, Length: 294, dtype: int64

# %%
df['attack1'] = [int(i.split('/')[0]) for i in df['攻击']]
df['attack2'] = [int(i.split('/')[1]) for i in df['攻击']]

# %%
df['defence1'] = [int(i.split('/')[0]) for i in df['防御']]
df['defence2'] = [int(i.split('/')[1]) for i in df['防御']]

# %%
df.to_csv('ArkModified2.csv')

# %%
df2 = pd.read_json('ArkOperators_final.json')

# %%
for i in range(229,294):
    if type(df2['身高'][i]) == str: 
        print(df['身高'][i],i)
        df2['身高'][i]= float(df2['身高'][i][:2])
    #print(type(df2['身高'][i]))

df2['身高']
# Out:
# 172 229
# 172 230
# 172 231
# 172 232
# 172 233
# 172 234
# 172 235
# 172 236
# 172 237
# 172 238
# 172 239
# 172 240
# 172 241
# 172 242
# 172 243
# 172 244
# 172 245
# 172 246
# 172 247
# 172 248
# 172 249
# 172 250
# 172 251
# 172 252
# 172 253
# 172 254
# 172 255
# 172 256
# 172 257
# 172 258
# 172 259
# 172 260
# 172 261
# 172 262
# 172 263
# 172 264
# 172 265
# 172 266
# 172 267
# 172 268
# 172 269
# 172 270
# 172 271
# 172 272
# 172 273
# 172 274
# 172 275
# 172 276
# 172 277
# 172 278
# 172 279
# 172 280
# 172 281
# 172 282
# 172 283
# 172 284
# 172 286
# 172 287
# 172 288
# 172 289
# 172 291
# 172 292
# 172 293
# 0      172.0
# 1      167.0
# 2      164.0
# 3      166.0
# 4      159.0
#        ...
# 289     16.0
# 290      NaN
# 291     14.0
# 292     15.0
# 293     16.0
# Name: 身高, Length: 294, dtype: object

# %%
df2['身高']
# Out:
# 0      172.0
# 1      167.0
# 2      164.0
# 3      166.0
# 4      159.0
#        ...
# 289     16.0
# 290      NaN
# 291     14.0
# 292     15.0
# 293     16.0
# Name: 身高, Length: 294, dtype: object

# %%
df2.to_csv('ArkOriginal.csv')

# %%
df3 = pd.read_csv('ArkOriginal.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df3 = pd.read_csv('ArkOriginal.csv')
#
# File f:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...
